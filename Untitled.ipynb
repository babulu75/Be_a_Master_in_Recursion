# %%
class TreeNode:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class Tree:
    def __init__(self):
        self.root=None
    nn=TreeNode(data)
    if self.root==None:
        self.root=nn
    else:
        if self.root.left==None:
            self.
# Out:
#   Cell In[1], line 12
#     else:
#          ^
# _IncompleteInputError: incomplete input
